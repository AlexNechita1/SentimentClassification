# %% [markdown]
# # Incarcarea setului de date

# %%
from pyspark.sql import SparkSession
import time

spark = SparkSession.builder \
    .appName("SteamReviewsClassifier") \
    .config("spark.driver.memory", "16g") \
    .config("spark.executor.memory", "16g") \
    .getOrCreate()
print("SparkSession creat")

path = "/kaggle/input/steam-reviews/dataset.csv"  

start = time.time()

df = spark.read.csv(path, header=True, inferSchema=True)
df = df.repartition(100)


end = time.time()
print("Timp încărcare dataset: {:.2f} secunde".format(end - start))

df.printSchema()
df.show(5)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/20 06:42:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SparkSession creat
# Timp încărcare dataset: 26.49 secunde
# root
#  |-- app_id: integer (nullable = true)
#  |-- app_name: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- review_score: integer (nullable = true)
#  |-- review_votes: integer (nullable = true)
# [Stage 2:===================================================================>         (15 + 2) / 17]
# +------+--------------------+--------------------+------------+------------+
# |app_id|            app_name|         review_text|review_score|review_votes|
# +------+--------------------+--------------------+------------+------------+
# | 17080|      Tribes: Ascend|Tribes: Ascend is...|          -1|           0|
# | 10090|Call of Duty: Wor...|Died from the oth...|           1|           0|
# | 17410|       Mirror's Edge|Probably my favou...|           1|           0|
# |113400|        APB Reloaded|keeps being ♥♥♥♥♥...|           1|           0|
# |107410|              Arma 3|10/10 would shoot...|           1|           0|
# +------+--------------------+--------------------+------------+------------+
# only showing top 5 rows

# %% [markdown]
# # Preprocesarea datelor

# %%
# !pip install vaderSentiment
from pyspark.sql.functions import col, lower, trim, udf
from pyspark.sql.types import IntegerType
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import time
import re

start = time.time()
# Normalizare si filtrare text 
df_clean = df.withColumn("review_text", lower(trim(col("review_text")))) \
             .withColumn("app_name", trim(col("app_name"))) \
             .filter(col("review_text").isNotNull()) \
             .filter(col("review_text") != "") \
             .filter(col("app_name").isNotNull()) \
             .filter(col("app_name") != "")

# UDF pentru analiza de sentiment
analyzer = SentimentIntensityAnalyzer()

def vader_sentiment(text):
    if text is None:
        return 1
    text = re.sub(r"[^\w\s]", "", text.lower())
    score = analyzer.polarity_scores(text)['compound']
    if score > 0.05:
        return 2
    elif score < -0.05:
        return 0
    else:
        return 1

vader_udf = udf(vader_sentiment, IntegerType())

df_labeled = df_clean.withColumn("label", vader_udf(col("review_text")))

# Vectorizare
from pyspark.ml.feature import Tokenizer, StopWordsRemover, HashingTF, IDF

tokenizer = Tokenizer(inputCol="review_text", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
hashingTF = HashingTF(inputCol="filtered", outputCol="rawFeatures", numFeatures=10000)
idf = IDF(inputCol="rawFeatures", outputCol="features")

df_words = tokenizer.transform(df_labeled)
df_filtered = remover.transform(df_words)
df_featurized = hashingTF.transform(df_filtered)
idfModel = idf.fit(df_featurized)
df_tfidf = idfModel.transform(df_featurized)

end = time.time()
print(f"Timp preprocesare: {end - start:.2f} secunde")

# df_labeled.select("app_name", "review_text", "label").show(5, truncate=False)
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2025.4.26)
# [Stage 7:==========================================================================> (98 + 2) / 100]
# Timp preprocesare: 306.69 secunde

# %% [markdown]
# # Naive Bayes Model

# %%
import time
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.classification import NaiveBayes

train_df, test_df = df_tfidf.randomSplit([0.8, 0.2], seed=42)
# Antrenare model 
start = time.time()
nb = NaiveBayes(featuresCol="features", labelCol="label")
nb_model = nb.fit(train_df)
end = time.time()
print(f"Timp antrenare Naive Bayes: {end - start:.2f} secunde")

# Predictii
predictions = nb_model.transform(test_df)

# Evaluare model
evaluator_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")

accuracy = evaluator_acc.evaluate(predictions)
f1 = evaluator_f1.evaluate(predictions)
precision = evaluator_precision.evaluate(predictions)
recall = evaluator_recall.evaluate(predictions)

print(f"Acuratețe: {accuracy:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"Precizie: {precision:.4f}")
print(f"Recall: {recall:.4f}")

# %% [markdown]
# # Linear SVC Model

# %%
from pyspark.ml.classification import LinearSVC, OneVsRest
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
import time

train_df, test_df = df_tfidf.randomSplit([0.8, 0.2], seed=42)

# Definire clasificador linear SVM (binary)
svm = LinearSVC(maxIter=100, regParam=0.1, featuresCol="features", labelCol="label")

# OneVsRest pentru multiclass
ovr = OneVsRest(classifier=svm)

# Antrenare și timp
start = time.time()
ovr_model = ovr.fit(train_df)
end = time.time()
print(f"Timp antrenare OneVsRest SVM: {end - start:.2f} secunde")

# Predictii
predictions = ovr_model.transform(test_df)

# Evaluare
evaluator_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")

accuracy = evaluator_acc.evaluate(predictions)
f1 = evaluator_f1.evaluate(predictions)
precision = evaluator_precision.evaluate(predictions)
recall = evaluator_recall.evaluate(predictions)

print(f"Acuratețe: {accuracy:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"Precizie: {precision:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# 25/06/18 09:18:10 WARN DAGScheduler: Broadcasting large task binary with size 1076.8 KiB6 + 1) / 17]
# 25/06/18 09:58:05 WARN DAGScheduler: Broadcasting large task binary with size 1079.0 KiB6 + 1) / 17]
# 25/06/18 10:37:35 WARN DAGScheduler: Broadcasting large task binary with size 1115.5 KiB + 1) / 100]
# 25/06/18 10:37:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.6 KiB + 1) / 100]
# 25/06/18 10:37:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:14 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:38:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:16 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:18 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:23 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:25 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:38:25 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:27 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:27 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:29 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 7) / 100]
# 25/06/18 10:38:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:31 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:31 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:33 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:33 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:35 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:38:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:42 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:44 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:38:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:46 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:38:46 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:48 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:38:48 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:50 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:57 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:38:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:38:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:38:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:07 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:39:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:09 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:09 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:11 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:11 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:14 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:16 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:39:18 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:20 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:39:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:23 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:25 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:27 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:39:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:29 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:39:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:31 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:31 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:33 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:33 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:35 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:37 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:39 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:39:39 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:39:41 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:39:43 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:45 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:51 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:39:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:53 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:53 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:55 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 10:39:55 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:57 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:57 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:39:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:39:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:00 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:40:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:09 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:11 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:12 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:13 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:14 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:20 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:32 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:40:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:34 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:34 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:36 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:45 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:51 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:53 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:53 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:40:58 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:40:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:00 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:00 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:02 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:41:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:41:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:09 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:41:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:12 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:14 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:16 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:18 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:41:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:41:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:29 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:30 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:32 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:41:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:34 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:34 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:37 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:39 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:41:39 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:41:41 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:48 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:51 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:53 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:41:53 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:41:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:41:57 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:41:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:41:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:02 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:04 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:06 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:08 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:12 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:13 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:23 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:42:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:25 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:31 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:32 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:33 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:34 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:34 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:36 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:38 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:42:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:42 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:43 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:42:43 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:45 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:42:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:42:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:58 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:42:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:42:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:43:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:43:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:07 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:09 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:12 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:13 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:43:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:25 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:43:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:30 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:32 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 10:43:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:33 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 10:43:34 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:38 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:41 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:43 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:43:43 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:45 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:46 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 0) / 100]
# 25/06/18 10:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:02 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:20 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:20 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:44:22 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:44:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:44:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:27 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:29 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 10:44:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:31 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:31 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:33 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:44:33 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:34 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:35 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:36 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:44:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:38 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:42 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:44 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 10:44:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 10:44:46 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:57 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:44:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:44:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:08 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:11 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:45:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:13 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:13 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:18 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 10:45:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 10:45:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:30 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 10:45:31 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 10:45:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# ...
# 25/06/18 12:00:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:16 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:16 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:18 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:18 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:20 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:20 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:22 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:23 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:00:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:25 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:25 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:27 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:31 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:32 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:34 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:34 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:36 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:37 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:39 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:00:39 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:41 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:43 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:44 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 12:00:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:46 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:48 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 2) / 100]
# 25/06/18 12:00:50 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:54 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:00:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:58 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:00:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:00:59 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:00:59 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:01 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:04 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:06 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:08 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 6) / 100]
# 25/06/18 12:01:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:11 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:13 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:13 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:15 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:16 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:18 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:21 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:23 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:25 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:01:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:28 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:30 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:31 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:32 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:33 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:33 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:35 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 3) / 100]
# 25/06/18 12:01:35 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:37 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:37 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:38 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 12:01:38 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:40 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:40 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:42 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:43 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:45 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 12:01:45 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:47 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:47 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:49 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:50 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:51 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:52 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:52 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:54 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 12:01:55 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:56 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:01:56 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:01:58 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:01:58 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:00 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:00 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:01 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:02:02 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:03 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 1) / 100]
# 25/06/18 12:02:03 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:05 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:05 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:06 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:07 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:08 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:08 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:10 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:10 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:12 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:02:12 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:14 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:14 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# 25/06/18 12:02:16 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:17 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:17 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:19 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:19 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:20 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:22 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:23 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:24 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:24 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:26 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 4) / 100]
# 25/06/18 12:02:26 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:28 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 0) / 100]
# 25/06/18 12:02:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.0 KiB
# 25/06/18 12:02:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB + 5) / 100]
# Timp antrenare OneVsRest SVM: 9899.80 secunde
# 25/06/18 12:03:10 WARN DAGScheduler: Broadcasting large task binary with size 1364.5 KiB6 + 1) / 17]
# 25/06/18 12:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1364.5 KiB6 + 1) / 17]
# 25/06/18 13:24:51 WARN DAGScheduler: Broadcasting large task binary with size 1364.5 KiB5 + 2) / 17]
# 25/06/18 14:05:49 WARN DAGScheduler: Broadcasting large task binary with size 1364.5 KiB6 + 1) / 17]
# [Stage 8438:=======================================================================> (98 + 2) / 100]
# Acuratețe: 0.7928
# F1-score: 0.7630
# Precizie: 0.8198
# Recall: 0.7928

# %% [markdown]
#  # Random Forest Classifier

# %%
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
import time

# Împărțirea datelor
train_df, test_df = df_tfidf.randomSplit([0.8, 0.2], seed=42)

# Definirea clasificatorului Random Forest
rf = RandomForestClassifier(featuresCol="features", labelCol="label", numTrees=20, maxDepth=5, seed=42)

# Antrenare și măsurare timp
start = time.time()
rf_model = rf.fit(train_df)
end = time.time()
print(f"Timp antrenare Random Forest: {end - start:.2f} secunde")

# Predictii pe test
predictions = rf_model.transform(test_df)

# Evaluare
evaluator_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")

accuracy = evaluator_acc.evaluate(predictions)
f1 = evaluator_f1.evaluate(predictions)
precision = evaluator_precision.evaluate(predictions)
recall = evaluator_recall.evaluate(predictions)

print(f"Acuratețe: {accuracy:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"Precizie: {precision:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# 25/06/20 06:50:39 WARN DAGScheduler: Broadcasting large task binary with size 1086.4 KiB6 + 1) / 17]
# 25/06/20 07:32:37 WARN DAGScheduler: Broadcasting large task binary with size 1108.8 KiB6 + 1) / 17]
# 25/06/20 07:33:21 WARN DAGScheduler: Broadcasting large task binary with size 1108.8 KiB
# 25/06/20 08:14:38 WARN DAGScheduler: Broadcasting large task binary with size 1213.0 KiB
# 25/06/20 08:55:59 WARN DAGScheduler: Broadcasting large task binary with size 1424.0 KiB
# 25/06/20 08:57:59 WARN MemoryStore: Not enough space to cache rdd_81_0 in memory! (computed 1553.0 MiB so far)
# 25/06/20 08:57:59 WARN BlockManager: Persisting block rdd_81_0 to disk instead.
# 25/06/20 08:59:46 WARN MemoryStore: Not enough space to cache rdd_81_6 in memory! (computed 129.6 MiB so far)
# 25/06/20 08:59:46 WARN BlockManager: Persisting block rdd_81_6 to disk instead.
# 25/06/20 08:59:46 WARN MemoryStore: Not enough space to cache rdd_81_4 in memory! (computed 443.6 MiB so far)
# 25/06/20 08:59:46 WARN BlockManager: Persisting block rdd_81_4 to disk instead.
# 25/06/20 08:59:46 WARN MemoryStore: Not enough space to cache rdd_81_5 in memory! (computed 443.6 MiB so far)
# 25/06/20 08:59:46 WARN BlockManager: Persisting block rdd_81_5 to disk instead.
# 25/06/20 09:00:06 WARN MemoryStore: Not enough space to cache rdd_81_7 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:00:06 WARN BlockManager: Persisting block rdd_81_7 to disk instead.
# 25/06/20 09:00:11 WARN MemoryStore: Not enough space to cache rdd_81_4 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:00:12 WARN MemoryStore: Not enough space to cache rdd_81_5 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:00:18 WARN MemoryStore: Not enough space to cache rdd_81_6 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:00:32 WARN MemoryStore: Not enough space to cache rdd_81_7 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:02:04 WARN MemoryStore: Not enough space to cache rdd_81_9 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:02:04 WARN BlockManager: Persisting block rdd_81_9 to disk instead.
# 25/06/20 09:02:04 WARN MemoryStore: Not enough space to cache rdd_81_8 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:02:04 WARN BlockManager: Persisting block rdd_81_8 to disk instead.
# 25/06/20 09:02:16 WARN MemoryStore: Not enough space to cache rdd_81_10 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:02:16 WARN BlockManager: Persisting block rdd_81_10 to disk instead.
# 25/06/20 09:02:30 WARN MemoryStore: Not enough space to cache rdd_81_9 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:02:31 WARN MemoryStore: Not enough space to cache rdd_81_8 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:02:42 WARN MemoryStore: Not enough space to cache rdd_81_11 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:02:42 WARN BlockManager: Persisting block rdd_81_11 to disk instead.
# 25/06/20 09:02:43 WARN MemoryStore: Not enough space to cache rdd_81_10 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:04:15 WARN MemoryStore: Not enough space to cache rdd_81_13 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:04:15 WARN BlockManager: Persisting block rdd_81_13 to disk instead.
# 25/06/20 09:04:16 WARN MemoryStore: Not enough space to cache rdd_81_12 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:04:16 WARN BlockManager: Persisting block rdd_81_12 to disk instead.
# 25/06/20 09:04:35 WARN MemoryStore: Not enough space to cache rdd_81_13 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:04:38 WARN MemoryStore: Not enough space to cache rdd_81_14 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:04:38 WARN BlockManager: Persisting block rdd_81_14 to disk instead.
# 25/06/20 09:04:39 WARN MemoryStore: Not enough space to cache rdd_81_12 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:04:51 WARN MemoryStore: Not enough space to cache rdd_81_15 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:04:51 WARN BlockManager: Persisting block rdd_81_15 to disk instead.
# 25/06/20 09:04:55 WARN MemoryStore: Not enough space to cache rdd_81_14 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:05:12 WARN MemoryStore: Not enough space to cache rdd_81_15 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:06:23 WARN MemoryStore: Not enough space to cache rdd_81_16 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:06:23 WARN BlockManager: Persisting block rdd_81_16 to disk instead.
# 25/06/20 09:06:25 WARN MemoryStore: Not enough space to cache rdd_81_17 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:06:25 WARN BlockManager: Persisting block rdd_81_17 to disk instead.
# 25/06/20 09:06:44 WARN MemoryStore: Not enough space to cache rdd_81_16 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:06:48 WARN MemoryStore: Not enough space to cache rdd_81_17 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:06:52 WARN MemoryStore: Not enough space to cache rdd_81_18 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:06:52 WARN BlockManager: Persisting block rdd_81_18 to disk instead.
# 25/06/20 09:07:03 WARN MemoryStore: Not enough space to cache rdd_81_19 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:07:03 WARN BlockManager: Persisting block rdd_81_19 to disk instead.
# 25/06/20 09:07:12 WARN MemoryStore: Not enough space to cache rdd_81_18 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:07:23 WARN MemoryStore: Not enough space to cache rdd_81_19 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:08:34 WARN MemoryStore: Not enough space to cache rdd_81_20 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:08:34 WARN BlockManager: Persisting block rdd_81_20 to disk instead.
# 25/06/20 09:08:34 WARN MemoryStore: Not enough space to cache rdd_81_21 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:08:34 WARN BlockManager: Persisting block rdd_81_21 to disk instead.
# 25/06/20 09:08:56 WARN MemoryStore: Not enough space to cache rdd_81_21 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:08:57 WARN MemoryStore: Not enough space to cache rdd_81_22 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:08:57 WARN BlockManager: Persisting block rdd_81_22 to disk instead.
# 25/06/20 09:08:57 WARN MemoryStore: Not enough space to cache rdd_81_20 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:09:10 WARN MemoryStore: Not enough space to cache rdd_81_23 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:09:10 WARN BlockManager: Persisting block rdd_81_23 to disk instead.
# 25/06/20 09:09:24 WARN MemoryStore: Not enough space to cache rdd_81_22 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:09:25 WARN MemoryStore: Not enough space to cache rdd_81_23 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:10:44 WARN MemoryStore: Not enough space to cache rdd_81_25 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:10:44 WARN BlockManager: Persisting block rdd_81_25 to disk instead.
# 25/06/20 09:10:44 WARN MemoryStore: Not enough space to cache rdd_81_24 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:10:44 WARN BlockManager: Persisting block rdd_81_24 to disk instead.
# 25/06/20 09:11:06 WARN MemoryStore: Not enough space to cache rdd_81_25 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:11:07 WARN MemoryStore: Not enough space to cache rdd_81_24 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:11:13 WARN MemoryStore: Not enough space to cache rdd_81_27 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:11:13 WARN BlockManager: Persisting block rdd_81_27 to disk instead.
# 25/06/20 09:11:16 WARN MemoryStore: Not enough space to cache rdd_81_26 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:11:16 WARN BlockManager: Persisting block rdd_81_26 to disk instead.
# 25/06/20 09:11:35 WARN MemoryStore: Not enough space to cache rdd_81_27 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:11:36 WARN MemoryStore: Not enough space to cache rdd_81_26 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:12:50 WARN MemoryStore: Not enough space to cache rdd_81_28 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:12:50 WARN BlockManager: Persisting block rdd_81_28 to disk instead.
# 25/06/20 09:12:51 WARN MemoryStore: Not enough space to cache rdd_81_29 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:12:51 WARN BlockManager: Persisting block rdd_81_29 to disk instead.
# 25/06/20 09:13:14 WARN MemoryStore: Not enough space to cache rdd_81_29 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:13:14 WARN MemoryStore: Not enough space to cache rdd_81_28 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:13:26 WARN MemoryStore: Not enough space to cache rdd_81_31 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:13:26 WARN BlockManager: Persisting block rdd_81_31 to disk instead.
# 25/06/20 09:13:26 WARN MemoryStore: Not enough space to cache rdd_81_30 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:13:26 WARN BlockManager: Persisting block rdd_81_30 to disk instead.
# 25/06/20 09:13:46 WARN MemoryStore: Not enough space to cache rdd_81_30 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:13:48 WARN MemoryStore: Not enough space to cache rdd_81_31 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:15:02 WARN MemoryStore: Not enough space to cache rdd_81_33 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:15:02 WARN BlockManager: Persisting block rdd_81_33 to disk instead.
# 25/06/20 09:15:03 WARN MemoryStore: Not enough space to cache rdd_81_32 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:15:03 WARN BlockManager: Persisting block rdd_81_32 to disk instead.
# 25/06/20 09:15:24 WARN MemoryStore: Not enough space to cache rdd_81_33 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:15:25 WARN MemoryStore: Not enough space to cache rdd_81_32 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:15:36 WARN MemoryStore: Not enough space to cache rdd_81_35 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:15:36 WARN BlockManager: Persisting block rdd_81_35 to disk instead.
# 25/06/20 09:15:36 WARN MemoryStore: Not enough space to cache rdd_81_34 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:15:36 WARN BlockManager: Persisting block rdd_81_34 to disk instead.
# 25/06/20 09:15:56 WARN MemoryStore: Not enough space to cache rdd_81_34 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:15:59 WARN MemoryStore: Not enough space to cache rdd_81_35 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:17:11 WARN MemoryStore: Not enough space to cache rdd_81_36 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:17:11 WARN BlockManager: Persisting block rdd_81_36 to disk instead.
# 25/06/20 09:17:14 WARN MemoryStore: Not enough space to cache rdd_81_37 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:17:14 WARN BlockManager: Persisting block rdd_81_37 to disk instead.
# 25/06/20 09:17:35 WARN MemoryStore: Not enough space to cache rdd_81_36 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:17:37 WARN MemoryStore: Not enough space to cache rdd_81_37 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:17:47 WARN MemoryStore: Not enough space to cache rdd_81_39 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:17:47 WARN BlockManager: Persisting block rdd_81_39 to disk instead.
# 25/06/20 09:17:48 WARN MemoryStore: Not enough space to cache rdd_81_38 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:17:48 WARN BlockManager: Persisting block rdd_81_38 to disk instead.
# 25/06/20 09:18:09 WARN MemoryStore: Not enough space to cache rdd_81_38 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:18:09 WARN MemoryStore: Not enough space to cache rdd_81_39 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:19:23 WARN MemoryStore: Not enough space to cache rdd_81_41 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:19:23 WARN BlockManager: Persisting block rdd_81_41 to disk instead.
# 25/06/20 09:19:23 WARN MemoryStore: Not enough space to cache rdd_81_40 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:19:23 WARN BlockManager: Persisting block rdd_81_40 to disk instead.
# 25/06/20 09:19:42 WARN MemoryStore: Not enough space to cache rdd_81_40 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:19:51 WARN MemoryStore: Not enough space to cache rdd_81_41 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:19:53 WARN MemoryStore: Not enough space to cache rdd_81_42 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:19:53 WARN BlockManager: Persisting block rdd_81_42 to disk instead.
# 25/06/20 09:20:10 WARN MemoryStore: Not enough space to cache rdd_81_43 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:20:10 WARN BlockManager: Persisting block rdd_81_43 to disk instead.
# 25/06/20 09:20:23 WARN MemoryStore: Not enough space to cache rdd_81_42 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:20:31 WARN MemoryStore: Not enough space to cache rdd_81_43 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:21:38 WARN MemoryStore: Not enough space to cache rdd_81_44 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:21:38 WARN BlockManager: Persisting block rdd_81_44 to disk instead.
# 25/06/20 09:21:40 WARN MemoryStore: Not enough space to cache rdd_81_45 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:21:40 WARN BlockManager: Persisting block rdd_81_45 to disk instead.
# 25/06/20 09:21:56 WARN MemoryStore: Not enough space to cache rdd_81_44 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:22:08 WARN MemoryStore: Not enough space to cache rdd_81_46 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:22:08 WARN BlockManager: Persisting block rdd_81_46 to disk instead.
# 25/06/20 09:22:08 WARN MemoryStore: Not enough space to cache rdd_81_45 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:22:26 WARN MemoryStore: Not enough space to cache rdd_81_47 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:22:26 WARN BlockManager: Persisting block rdd_81_47 to disk instead.
# 25/06/20 09:22:35 WARN MemoryStore: Not enough space to cache rdd_81_46 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:22:49 WARN MemoryStore: Not enough space to cache rdd_81_47 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:23:46 WARN MemoryStore: Not enough space to cache rdd_81_48 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:23:46 WARN BlockManager: Persisting block rdd_81_48 to disk instead.
# 25/06/20 09:24:00 WARN MemoryStore: Not enough space to cache rdd_81_49 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:24:00 WARN BlockManager: Persisting block rdd_81_49 to disk instead.
# 25/06/20 09:24:04 WARN MemoryStore: Not enough space to cache rdd_81_48 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:24:19 WARN MemoryStore: Not enough space to cache rdd_81_49 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:24:20 WARN MemoryStore: Not enough space to cache rdd_81_50 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:24:20 WARN BlockManager: Persisting block rdd_81_50 to disk instead.
# 25/06/20 09:24:37 WARN MemoryStore: Not enough space to cache rdd_81_51 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:24:37 WARN BlockManager: Persisting block rdd_81_51 to disk instead.
# 25/06/20 09:24:45 WARN MemoryStore: Not enough space to cache rdd_81_50 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:25:00 WARN MemoryStore: Not enough space to cache rdd_81_51 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:26:03 WARN MemoryStore: Not enough space to cache rdd_81_52 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:26:03 WARN BlockManager: Persisting block rdd_81_52 to disk instead.
# 25/06/20 09:26:19 WARN MemoryStore: Not enough space to cache rdd_81_53 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:26:19 WARN BlockManager: Persisting block rdd_81_53 to disk instead.
# 25/06/20 09:26:21 WARN MemoryStore: Not enough space to cache rdd_81_52 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:26:38 WARN MemoryStore: Not enough space to cache rdd_81_53 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:26:44 WARN MemoryStore: Not enough space to cache rdd_81_54 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:26:44 WARN BlockManager: Persisting block rdd_81_54 to disk instead.
# 25/06/20 09:26:48 WARN MemoryStore: Not enough space to cache rdd_81_55 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:26:48 WARN BlockManager: Persisting block rdd_81_55 to disk instead.
# 25/06/20 09:27:04 WARN MemoryStore: Not enough space to cache rdd_81_54 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:28:09 WARN MemoryStore: Not enough space to cache rdd_81_56 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:28:09 WARN BlockManager: Persisting block rdd_81_56 to disk instead.
# 25/06/20 09:28:27 WARN MemoryStore: Not enough space to cache rdd_81_56 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:28:29 WARN MemoryStore: Not enough space to cache rdd_81_57 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:28:29 WARN BlockManager: Persisting block rdd_81_57 to disk instead.
# 25/06/20 09:28:47 WARN MemoryStore: Not enough space to cache rdd_81_57 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:29:03 WARN MemoryStore: Not enough space to cache rdd_81_58 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:29:03 WARN BlockManager: Persisting block rdd_81_58 to disk instead.
# 25/06/20 09:29:07 WARN MemoryStore: Not enough space to cache rdd_81_59 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:29:07 WARN BlockManager: Persisting block rdd_81_59 to disk instead.
# 25/06/20 09:29:23 WARN MemoryStore: Not enough space to cache rdd_81_58 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:29:35 WARN MemoryStore: Not enough space to cache rdd_81_59 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:30:21 WARN MemoryStore: Not enough space to cache rdd_81_60 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:30:21 WARN BlockManager: Persisting block rdd_81_60 to disk instead.
# 25/06/20 09:30:39 WARN MemoryStore: Not enough space to cache rdd_81_61 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:30:39 WARN BlockManager: Persisting block rdd_81_61 to disk instead.
# 25/06/20 09:30:40 WARN MemoryStore: Not enough space to cache rdd_81_60 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:30:57 WARN MemoryStore: Not enough space to cache rdd_81_61 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:31:17 WARN MemoryStore: Not enough space to cache rdd_81_62 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:31:17 WARN BlockManager: Persisting block rdd_81_62 to disk instead.
# 25/06/20 09:31:20 WARN MemoryStore: Not enough space to cache rdd_81_63 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:31:20 WARN BlockManager: Persisting block rdd_81_63 to disk instead.
# 25/06/20 09:31:37 WARN MemoryStore: Not enough space to cache rdd_81_62 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:32:29 WARN MemoryStore: Not enough space to cache rdd_81_64 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:32:29 WARN BlockManager: Persisting block rdd_81_64 to disk instead.
# 25/06/20 09:32:48 WARN MemoryStore: Not enough space to cache rdd_81_64 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:32:48 WARN MemoryStore: Not enough space to cache rdd_81_65 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:32:48 WARN BlockManager: Persisting block rdd_81_65 to disk instead.
# 25/06/20 09:33:07 WARN MemoryStore: Not enough space to cache rdd_81_65 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:34:57 WARN MemoryStore: Not enough space to cache rdd_81_68 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:35:00 WARN MemoryStore: Not enough space to cache rdd_81_69 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:35:00 WARN BlockManager: Persisting block rdd_81_69 to disk instead.
# 25/06/20 09:35:19 WARN MemoryStore: Not enough space to cache rdd_81_69 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:35:40 WARN MemoryStore: Not enough space to cache rdd_81_70 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:35:40 WARN BlockManager: Persisting block rdd_81_70 to disk instead.
# 25/06/20 09:35:59 WARN MemoryStore: Not enough space to cache rdd_81_71 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:35:59 WARN BlockManager: Persisting block rdd_81_71 to disk instead.
# 25/06/20 09:36:00 WARN MemoryStore: Not enough space to cache rdd_81_70 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:36:23 WARN MemoryStore: Not enough space to cache rdd_81_71 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:36:49 WARN MemoryStore: Not enough space to cache rdd_81_72 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:36:49 WARN BlockManager: Persisting block rdd_81_72 to disk instead.
# 25/06/20 09:37:08 WARN MemoryStore: Not enough space to cache rdd_81_72 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:37:08 WARN MemoryStore: Not enough space to cache rdd_81_73 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:37:08 WARN BlockManager: Persisting block rdd_81_73 to disk instead.
# 25/06/20 09:37:31 WARN MemoryStore: Not enough space to cache rdd_81_73 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:37:50 WARN MemoryStore: Not enough space to cache rdd_81_74 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:37:50 WARN BlockManager: Persisting block rdd_81_74 to disk instead.
# 25/06/20 09:38:10 WARN MemoryStore: Not enough space to cache rdd_81_74 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:38:16 WARN MemoryStore: Not enough space to cache rdd_81_75 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:38:16 WARN BlockManager: Persisting block rdd_81_75 to disk instead.
# 25/06/20 09:38:35 WARN MemoryStore: Not enough space to cache rdd_81_75 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:38:56 WARN MemoryStore: Not enough space to cache rdd_81_76 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:38:56 WARN BlockManager: Persisting block rdd_81_76 to disk instead.
# 25/06/20 09:39:15 WARN MemoryStore: Not enough space to cache rdd_81_77 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:39:15 WARN BlockManager: Persisting block rdd_81_77 to disk instead.
# 25/06/20 09:39:15 WARN MemoryStore: Not enough space to cache rdd_81_76 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:39:42 WARN MemoryStore: Not enough space to cache rdd_81_77 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:40:05 WARN MemoryStore: Not enough space to cache rdd_81_78 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:40:05 WARN BlockManager: Persisting block rdd_81_78 to disk instead.
# 25/06/20 09:40:24 WARN MemoryStore: Not enough space to cache rdd_81_79 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:40:24 WARN BlockManager: Persisting block rdd_81_79 to disk instead.
# 25/06/20 09:40:25 WARN MemoryStore: Not enough space to cache rdd_81_78 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:40:47 WARN MemoryStore: Not enough space to cache rdd_81_79 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:41:08 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:41:08 WARN BlockManager: Persisting block rdd_81_80 to disk instead.
# 25/06/20 09:41:28 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:41:28 WARN BlockManager: Persisting block rdd_81_81 to disk instead.
# 25/06/20 09:41:28 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:41:54 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:42:13 WARN MemoryStore: Not enough space to cache rdd_81_82 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:42:13 WARN BlockManager: Persisting block rdd_81_82 to disk instead.
# 25/06/20 09:42:32 WARN MemoryStore: Not enough space to cache rdd_81_82 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:42:39 WARN MemoryStore: Not enough space to cache rdd_81_83 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:42:39 WARN BlockManager: Persisting block rdd_81_83 to disk instead.
# 25/06/20 09:42:59 WARN MemoryStore: Not enough space to cache rdd_81_83 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:43:21 WARN MemoryStore: Not enough space to cache rdd_81_84 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:43:21 WARN BlockManager: Persisting block rdd_81_84 to disk instead.
# 25/06/20 09:43:42 WARN MemoryStore: Not enough space to cache rdd_81_85 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:43:42 WARN BlockManager: Persisting block rdd_81_85 to disk instead.
# 25/06/20 09:43:43 WARN MemoryStore: Not enough space to cache rdd_81_84 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:44:08 WARN MemoryStore: Not enough space to cache rdd_81_85 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:44:25 WARN MemoryStore: Not enough space to cache rdd_81_86 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:44:25 WARN BlockManager: Persisting block rdd_81_86 to disk instead.
# 25/06/20 09:44:45 WARN MemoryStore: Not enough space to cache rdd_81_86 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:44:57 WARN MemoryStore: Not enough space to cache rdd_81_87 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:44:57 WARN BlockManager: Persisting block rdd_81_87 to disk instead.
# 25/06/20 09:45:16 WARN MemoryStore: Not enough space to cache rdd_81_87 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:45:34 WARN MemoryStore: Not enough space to cache rdd_81_88 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:45:34 WARN BlockManager: Persisting block rdd_81_88 to disk instead.
# 25/06/20 09:45:52 WARN MemoryStore: Not enough space to cache rdd_81_88 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:45:55 WARN MemoryStore: Not enough space to cache rdd_81_89 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:45:55 WARN BlockManager: Persisting block rdd_81_89 to disk instead.
# 25/06/20 09:46:15 WARN MemoryStore: Not enough space to cache rdd_81_89 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:46:35 WARN MemoryStore: Not enough space to cache rdd_81_90 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:46:35 WARN BlockManager: Persisting block rdd_81_90 to disk instead.
# 25/06/20 09:46:56 WARN MemoryStore: Not enough space to cache rdd_81_90 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:47:06 WARN MemoryStore: Not enough space to cache rdd_81_91 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:47:06 WARN BlockManager: Persisting block rdd_81_91 to disk instead.
# 25/06/20 09:47:25 WARN MemoryStore: Not enough space to cache rdd_81_91 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:47:42 WARN MemoryStore: Not enough space to cache rdd_81_92 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:47:42 WARN BlockManager: Persisting block rdd_81_92 to disk instead.
# 25/06/20 09:48:01 WARN MemoryStore: Not enough space to cache rdd_81_92 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:48:07 WARN MemoryStore: Not enough space to cache rdd_81_93 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:48:07 WARN BlockManager: Persisting block rdd_81_93 to disk instead.
# 25/06/20 09:48:26 WARN MemoryStore: Not enough space to cache rdd_81_93 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:48:47 WARN MemoryStore: Not enough space to cache rdd_81_94 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:48:47 WARN BlockManager: Persisting block rdd_81_94 to disk instead.
# 25/06/20 09:49:06 WARN MemoryStore: Not enough space to cache rdd_81_94 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:49:18 WARN MemoryStore: Not enough space to cache rdd_81_95 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:49:18 WARN BlockManager: Persisting block rdd_81_95 to disk instead.
# 25/06/20 09:49:36 WARN MemoryStore: Not enough space to cache rdd_81_95 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:49:53 WARN MemoryStore: Not enough space to cache rdd_81_96 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:49:53 WARN BlockManager: Persisting block rdd_81_96 to disk instead.
# 25/06/20 09:50:12 WARN MemoryStore: Not enough space to cache rdd_81_96 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:50:18 WARN MemoryStore: Not enough space to cache rdd_81_97 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:50:18 WARN BlockManager: Persisting block rdd_81_97 to disk instead.
# 25/06/20 09:50:37 WARN MemoryStore: Not enough space to cache rdd_81_97 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:03 WARN MemoryStore: Not enough space to cache rdd_81_99 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:03 WARN BlockManager: Persisting block rdd_81_99 to disk instead.
# 25/06/20 09:51:11 WARN MemoryStore: Not enough space to cache rdd_81_99 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:15 WARN DAGScheduler: Broadcasting large task binary with size 1438.8 KiB
# 25/06/20 09:51:16 WARN MemoryStore: Not enough space to cache rdd_81_1 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:17 WARN MemoryStore: Not enough space to cache rdd_81_2 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:17 WARN MemoryStore: Not enough space to cache rdd_81_3 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:17 WARN MemoryStore: Not enough space to cache rdd_81_0 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:24 WARN MemoryStore: Not enough space to cache rdd_81_7 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:24 WARN MemoryStore: Not enough space to cache rdd_81_5 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:24 WARN MemoryStore: Not enough space to cache rdd_81_6 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:24 WARN MemoryStore: Not enough space to cache rdd_81_4 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:31 WARN MemoryStore: Not enough space to cache rdd_81_9 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:31 WARN MemoryStore: Not enough space to cache rdd_81_8 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:31 WARN MemoryStore: Not enough space to cache rdd_81_10 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:35 WARN MemoryStore: Not enough space to cache rdd_81_12 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:36 WARN MemoryStore: Not enough space to cache rdd_81_13 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:51:36 WARN MemoryStore: Not enough space to cache rdd_81_14 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:51:40 WARN MemoryStore: Not enough space to cache rdd_81_16 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:40 WARN MemoryStore: Not enough space to cache rdd_81_15 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:44 WARN MemoryStore: Not enough space to cache rdd_81_19 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:51:44 WARN MemoryStore: Not enough space to cache rdd_81_18 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:47 WARN MemoryStore: Not enough space to cache rdd_81_17 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:47 WARN MemoryStore: Not enough space to cache rdd_81_20 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:51:51 WARN MemoryStore: Not enough space to cache rdd_81_21 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:51 WARN MemoryStore: Not enough space to cache rdd_81_22 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:52 WARN MemoryStore: Not enough space to cache rdd_81_23 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:51:58 WARN MemoryStore: Not enough space to cache rdd_81_24 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:51:58 WARN MemoryStore: Not enough space to cache rdd_81_25 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:51:58 WARN MemoryStore: Not enough space to cache rdd_81_26 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:52:02 WARN MemoryStore: Not enough space to cache rdd_81_28 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:02 WARN MemoryStore: Not enough space to cache rdd_81_27 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:06 WARN MemoryStore: Not enough space to cache rdd_81_31 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:06 WARN MemoryStore: Not enough space to cache rdd_81_30 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:09 WARN MemoryStore: Not enough space to cache rdd_81_32 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:09 WARN MemoryStore: Not enough space to cache rdd_81_29 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:13 WARN MemoryStore: Not enough space to cache rdd_81_35 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:13 WARN MemoryStore: Not enough space to cache rdd_81_34 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:16 WARN MemoryStore: Not enough space to cache rdd_81_36 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:16 WARN MemoryStore: Not enough space to cache rdd_81_33 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:21 WARN MemoryStore: Not enough space to cache rdd_81_37 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:21 WARN MemoryStore: Not enough space to cache rdd_81_38 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:23 WARN MemoryStore: Not enough space to cache rdd_81_40 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:24 WARN MemoryStore: Not enough space to cache rdd_81_39 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:28 WARN MemoryStore: Not enough space to cache rdd_81_43 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:28 WARN MemoryStore: Not enough space to cache rdd_81_42 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:31 WARN MemoryStore: Not enough space to cache rdd_81_44 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:31 WARN MemoryStore: Not enough space to cache rdd_81_41 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:35 WARN MemoryStore: Not enough space to cache rdd_81_45 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:35 WARN MemoryStore: Not enough space to cache rdd_81_46 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:37 WARN MemoryStore: Not enough space to cache rdd_81_48 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:39 WARN MemoryStore: Not enough space to cache rdd_81_47 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:42 WARN MemoryStore: Not enough space to cache rdd_81_50 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:43 WARN MemoryStore: Not enough space to cache rdd_81_51 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:44 WARN MemoryStore: Not enough space to cache rdd_81_52 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:52:45 WARN MemoryStore: Not enough space to cache rdd_81_49 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:49 WARN MemoryStore: Not enough space to cache rdd_81_54 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:50 WARN MemoryStore: Not enough space to cache rdd_81_56 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:51 WARN MemoryStore: Not enough space to cache rdd_81_57 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:52:52 WARN MemoryStore: Not enough space to cache rdd_81_53 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:52:56 WARN MemoryStore: Not enough space to cache rdd_81_59 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:52:58 WARN MemoryStore: Not enough space to cache rdd_81_58 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:52:58 WARN MemoryStore: Not enough space to cache rdd_81_61 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:52:59 WARN MemoryStore: Not enough space to cache rdd_81_60 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:05 WARN MemoryStore: Not enough space to cache rdd_81_64 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:05 WARN MemoryStore: Not enough space to cache rdd_81_65 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:53:05 WARN MemoryStore: Not enough space to cache rdd_81_62 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:10 WARN MemoryStore: Not enough space to cache rdd_81_66 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:53:11 WARN MemoryStore: Not enough space to cache rdd_81_68 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:53:11 WARN MemoryStore: Not enough space to cache rdd_81_67 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:14 WARN MemoryStore: Not enough space to cache rdd_81_69 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:15 WARN MemoryStore: Not enough space to cache rdd_81_70 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:20 WARN MemoryStore: Not enough space to cache rdd_81_73 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:53:20 WARN MemoryStore: Not enough space to cache rdd_81_74 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:53:20 WARN MemoryStore: Not enough space to cache rdd_81_72 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:20 WARN MemoryStore: Not enough space to cache rdd_81_71 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:26 WARN MemoryStore: Not enough space to cache rdd_81_76 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:27 WARN MemoryStore: Not enough space to cache rdd_81_75 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:27 WARN MemoryStore: Not enough space to cache rdd_81_77 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:27 WARN MemoryStore: Not enough space to cache rdd_81_78 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:53:33 WARN MemoryStore: Not enough space to cache rdd_81_82 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:53:34 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:53:34 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:34 WARN MemoryStore: Not enough space to cache rdd_81_79 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:43 WARN MemoryStore: Not enough space to cache rdd_81_86 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:53:43 WARN MemoryStore: Not enough space to cache rdd_81_85 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:53:44 WARN MemoryStore: Not enough space to cache rdd_81_84 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:53:44 WARN MemoryStore: Not enough space to cache rdd_81_83 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:50 WARN MemoryStore: Not enough space to cache rdd_81_88 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:50 WARN MemoryStore: Not enough space to cache rdd_81_90 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:53:51 WARN MemoryStore: Not enough space to cache rdd_81_89 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:52 WARN MemoryStore: Not enough space to cache rdd_81_87 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:53:57 WARN MemoryStore: Not enough space to cache rdd_81_92 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:53:57 WARN MemoryStore: Not enough space to cache rdd_81_94 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:53:58 WARN MemoryStore: Not enough space to cache rdd_81_91 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:53:58 WARN MemoryStore: Not enough space to cache rdd_81_93 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:04 WARN MemoryStore: Not enough space to cache rdd_81_95 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:04 WARN MemoryStore: Not enough space to cache rdd_81_96 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:07 WARN MemoryStore: Not enough space to cache rdd_81_99 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:08 WARN MemoryStore: Not enough space to cache rdd_81_97 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:54:13 WARN DAGScheduler: Broadcasting large task binary with size 1466.1 KiB
# 25/06/20 09:54:14 WARN MemoryStore: Not enough space to cache rdd_81_0 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:14 WARN MemoryStore: Not enough space to cache rdd_81_2 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:14 WARN MemoryStore: Not enough space to cache rdd_81_3 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:17 WARN MemoryStore: Not enough space to cache rdd_81_1 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:54:21 WARN MemoryStore: Not enough space to cache rdd_81_5 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:21 WARN MemoryStore: Not enough space to cache rdd_81_6 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:22 WARN MemoryStore: Not enough space to cache rdd_81_4 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:22 WARN MemoryStore: Not enough space to cache rdd_81_7 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:28 WARN MemoryStore: Not enough space to cache rdd_81_9 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:29 WARN MemoryStore: Not enough space to cache rdd_81_8 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:29 WARN MemoryStore: Not enough space to cache rdd_81_10 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:54:34 WARN MemoryStore: Not enough space to cache rdd_81_12 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:54:34 WARN MemoryStore: Not enough space to cache rdd_81_15 in memory! (computed 36.4 MiB so far)
# 25/06/20 09:54:34 WARN MemoryStore: Not enough space to cache rdd_81_14 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:54:35 WARN MemoryStore: Not enough space to cache rdd_81_13 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:41 WARN MemoryStore: Not enough space to cache rdd_81_17 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:54:41 WARN MemoryStore: Not enough space to cache rdd_81_18 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:54:42 WARN MemoryStore: Not enough space to cache rdd_81_16 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:54:43 WARN MemoryStore: Not enough space to cache rdd_81_19 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:49 WARN MemoryStore: Not enough space to cache rdd_81_21 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:54:49 WARN MemoryStore: Not enough space to cache rdd_81_23 in memory! (computed 84.3 MiB so far)
# 25/06/20 09:54:49 WARN MemoryStore: Not enough space to cache rdd_81_22 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:54:50 WARN MemoryStore: Not enough space to cache rdd_81_20 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:54:56 WARN MemoryStore: Not enough space to cache rdd_81_26 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:54:56 WARN MemoryStore: Not enough space to cache rdd_81_27 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:54:57 WARN MemoryStore: Not enough space to cache rdd_81_25 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:54:57 WARN MemoryStore: Not enough space to cache rdd_81_24 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:55:03 WARN MemoryStore: Not enough space to cache rdd_81_30 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:03 WARN MemoryStore: Not enough space to cache rdd_81_28 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:55:03 WARN MemoryStore: Not enough space to cache rdd_81_31 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:55:04 WARN MemoryStore: Not enough space to cache rdd_81_29 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:11 WARN MemoryStore: Not enough space to cache rdd_81_33 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:11 WARN MemoryStore: Not enough space to cache rdd_81_34 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:11 WARN MemoryStore: Not enough space to cache rdd_81_35 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:11 WARN MemoryStore: Not enough space to cache rdd_81_32 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:55:18 WARN MemoryStore: Not enough space to cache rdd_81_37 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:55:18 WARN MemoryStore: Not enough space to cache rdd_81_38 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:18 WARN MemoryStore: Not enough space to cache rdd_81_39 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:55:20 WARN MemoryStore: Not enough space to cache rdd_81_36 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:55:25 WARN MemoryStore: Not enough space to cache rdd_81_41 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:55:25 WARN MemoryStore: Not enough space to cache rdd_81_42 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:25 WARN MemoryStore: Not enough space to cache rdd_81_43 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:55:28 WARN MemoryStore: Not enough space to cache rdd_81_40 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:55:32 WARN MemoryStore: Not enough space to cache rdd_81_46 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:32 WARN MemoryStore: Not enough space to cache rdd_81_44 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:32 WARN MemoryStore: Not enough space to cache rdd_81_47 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:32 WARN MemoryStore: Not enough space to cache rdd_81_45 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:38 WARN MemoryStore: Not enough space to cache rdd_81_50 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:39 WARN MemoryStore: Not enough space to cache rdd_81_48 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:39 WARN MemoryStore: Not enough space to cache rdd_81_51 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:55:42 WARN MemoryStore: Not enough space to cache rdd_81_49 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:55:46 WARN MemoryStore: Not enough space to cache rdd_81_53 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:55:46 WARN MemoryStore: Not enough space to cache rdd_81_54 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:55:48 WARN MemoryStore: Not enough space to cache rdd_81_56 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:55:49 WARN MemoryStore: Not enough space to cache rdd_81_52 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:55:53 WARN MemoryStore: Not enough space to cache rdd_81_57 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:54 WARN MemoryStore: Not enough space to cache rdd_81_58 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:55:54 WARN MemoryStore: Not enough space to cache rdd_81_60 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:55:57 WARN MemoryStore: Not enough space to cache rdd_81_59 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:56:01 WARN MemoryStore: Not enough space to cache rdd_81_62 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:56:02 WARN MemoryStore: Not enough space to cache rdd_81_65 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:56:02 WARN MemoryStore: Not enough space to cache rdd_81_64 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:56:03 WARN MemoryStore: Not enough space to cache rdd_81_61 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:56:08 WARN MemoryStore: Not enough space to cache rdd_81_67 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:56:09 WARN MemoryStore: Not enough space to cache rdd_81_68 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:56:11 WARN MemoryStore: Not enough space to cache rdd_81_69 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:56:11 WARN MemoryStore: Not enough space to cache rdd_81_66 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:56:16 WARN MemoryStore: Not enough space to cache rdd_81_71 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:56:16 WARN MemoryStore: Not enough space to cache rdd_81_72 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:56:18 WARN MemoryStore: Not enough space to cache rdd_81_73 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:56:18 WARN MemoryStore: Not enough space to cache rdd_81_70 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:56:24 WARN MemoryStore: Not enough space to cache rdd_81_75 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:56:24 WARN MemoryStore: Not enough space to cache rdd_81_76 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:56:24 WARN MemoryStore: Not enough space to cache rdd_81_77 in memory! (computed 24.2 MiB so far)
# 25/06/20 09:56:26 WARN MemoryStore: Not enough space to cache rdd_81_74 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:56:31 WARN MemoryStore: Not enough space to cache rdd_81_79 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:56:31 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:56:31 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 24.2 MiB so far)
# ...
# 25/06/20 09:59:31 WARN MemoryStore: Not enough space to cache rdd_81_78 in memory! (computed 1034.7 MiB so far)
# 25/06/20 09:59:33 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:59:36 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:59:36 WARN MemoryStore: Not enough space to cache rdd_81_83 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:59:36 WARN MemoryStore: Not enough space to cache rdd_81_82 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:59:41 WARN MemoryStore: Not enough space to cache rdd_81_85 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:59:44 WARN MemoryStore: Not enough space to cache rdd_81_87 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:59:44 WARN MemoryStore: Not enough space to cache rdd_81_84 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:59:44 WARN MemoryStore: Not enough space to cache rdd_81_86 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:59:49 WARN MemoryStore: Not enough space to cache rdd_81_89 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:59:51 WARN MemoryStore: Not enough space to cache rdd_81_91 in memory! (computed 129.6 MiB so far)
# 25/06/20 09:59:51 WARN MemoryStore: Not enough space to cache rdd_81_90 in memory! (computed 292.2 MiB so far)
# 25/06/20 09:59:51 WARN MemoryStore: Not enough space to cache rdd_81_88 in memory! (computed 1553.0 MiB so far)
# 25/06/20 09:59:56 WARN MemoryStore: Not enough space to cache rdd_81_93 in memory! (computed 689.2 MiB so far)
# 25/06/20 09:59:57 WARN MemoryStore: Not enough space to cache rdd_81_94 in memory! (computed 194.7 MiB so far)
# 25/06/20 09:59:58 WARN MemoryStore: Not enough space to cache rdd_81_95 in memory! (computed 443.6 MiB so far)
# 25/06/20 09:59:59 WARN MemoryStore: Not enough space to cache rdd_81_92 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:00:04 WARN MemoryStore: Not enough space to cache rdd_81_97 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:07 WARN MemoryStore: Not enough space to cache rdd_81_99 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:07 WARN MemoryStore: Not enough space to cache rdd_81_96 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:00:14 WARN DAGScheduler: Broadcasting large task binary with size 1623.5 KiB
# 25/06/20 10:00:16 WARN MemoryStore: Not enough space to cache rdd_81_0 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:16 WARN MemoryStore: Not enough space to cache rdd_81_3 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:16 WARN MemoryStore: Not enough space to cache rdd_81_1 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:16 WARN MemoryStore: Not enough space to cache rdd_81_2 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:23 WARN MemoryStore: Not enough space to cache rdd_81_5 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:24 WARN MemoryStore: Not enough space to cache rdd_81_7 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:24 WARN MemoryStore: Not enough space to cache rdd_81_6 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:24 WARN MemoryStore: Not enough space to cache rdd_81_4 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:31 WARN MemoryStore: Not enough space to cache rdd_81_8 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:31 WARN MemoryStore: Not enough space to cache rdd_81_9 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:31 WARN MemoryStore: Not enough space to cache rdd_81_10 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:00:37 WARN MemoryStore: Not enough space to cache rdd_81_12 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:00:37 WARN MemoryStore: Not enough space to cache rdd_81_14 in memory! (computed 129.6 MiB so far)
# 25/06/20 10:00:37 WARN MemoryStore: Not enough space to cache rdd_81_15 in memory! (computed 129.6 MiB so far)
# 25/06/20 10:00:38 WARN MemoryStore: Not enough space to cache rdd_81_13 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:44 WARN MemoryStore: Not enough space to cache rdd_81_17 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:00:45 WARN MemoryStore: Not enough space to cache rdd_81_16 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:00:45 WARN MemoryStore: Not enough space to cache rdd_81_19 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:00:45 WARN MemoryStore: Not enough space to cache rdd_81_18 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:00:52 WARN MemoryStore: Not enough space to cache rdd_81_21 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:00:52 WARN MemoryStore: Not enough space to cache rdd_81_23 in memory! (computed 84.3 MiB so far)
# 25/06/20 10:00:52 WARN MemoryStore: Not enough space to cache rdd_81_22 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:00:53 WARN MemoryStore: Not enough space to cache rdd_81_20 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:00:59 WARN MemoryStore: Not enough space to cache rdd_81_24 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:00:59 WARN MemoryStore: Not enough space to cache rdd_81_26 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:00:59 WARN MemoryStore: Not enough space to cache rdd_81_25 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:00:59 WARN MemoryStore: Not enough space to cache rdd_81_27 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:01:06 WARN MemoryStore: Not enough space to cache rdd_81_28 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:01:06 WARN MemoryStore: Not enough space to cache rdd_81_30 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:01:07 WARN MemoryStore: Not enough space to cache rdd_81_31 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:01:07 WARN MemoryStore: Not enough space to cache rdd_81_29 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:13 WARN MemoryStore: Not enough space to cache rdd_81_33 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:01:13 WARN MemoryStore: Not enough space to cache rdd_81_34 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:01:13 WARN MemoryStore: Not enough space to cache rdd_81_32 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:01:14 WARN MemoryStore: Not enough space to cache rdd_81_35 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:01:21 WARN MemoryStore: Not enough space to cache rdd_81_39 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:01:21 WARN MemoryStore: Not enough space to cache rdd_81_37 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:21 WARN MemoryStore: Not enough space to cache rdd_81_38 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:22 WARN MemoryStore: Not enough space to cache rdd_81_36 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:01:28 WARN MemoryStore: Not enough space to cache rdd_81_42 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:01:28 WARN MemoryStore: Not enough space to cache rdd_81_43 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:01:28 WARN MemoryStore: Not enough space to cache rdd_81_41 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:30 WARN MemoryStore: Not enough space to cache rdd_81_40 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:01:35 WARN MemoryStore: Not enough space to cache rdd_81_44 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:35 WARN MemoryStore: Not enough space to cache rdd_81_45 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:35 WARN MemoryStore: Not enough space to cache rdd_81_46 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:36 WARN MemoryStore: Not enough space to cache rdd_81_47 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:42 WARN MemoryStore: Not enough space to cache rdd_81_48 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:42 WARN MemoryStore: Not enough space to cache rdd_81_49 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:42 WARN MemoryStore: Not enough space to cache rdd_81_50 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:43 WARN MemoryStore: Not enough space to cache rdd_81_51 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:01:49 WARN MemoryStore: Not enough space to cache rdd_81_52 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:49 WARN MemoryStore: Not enough space to cache rdd_81_54 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:50 WARN MemoryStore: Not enough space to cache rdd_81_53 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:01:56 WARN MemoryStore: Not enough space to cache rdd_81_56 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:01:56 WARN MemoryStore: Not enough space to cache rdd_81_57 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:01:56 WARN MemoryStore: Not enough space to cache rdd_81_59 in memory! (computed 84.3 MiB so far)
# 25/06/20 10:01:56 WARN MemoryStore: Not enough space to cache rdd_81_58 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:03 WARN MemoryStore: Not enough space to cache rdd_81_62 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:03 WARN MemoryStore: Not enough space to cache rdd_81_61 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:03 WARN MemoryStore: Not enough space to cache rdd_81_60 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:08 WARN MemoryStore: Not enough space to cache rdd_81_64 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:02:08 WARN MemoryStore: Not enough space to cache rdd_81_65 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:11 WARN MemoryStore: Not enough space to cache rdd_81_66 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:13 WARN MemoryStore: Not enough space to cache rdd_81_69 in memory! (computed 24.2 MiB so far)
# 25/06/20 10:02:14 WARN MemoryStore: Not enough space to cache rdd_81_67 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:14 WARN MemoryStore: Not enough space to cache rdd_81_68 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:02:19 WARN MemoryStore: Not enough space to cache rdd_81_71 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:19 WARN MemoryStore: Not enough space to cache rdd_81_70 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:02:22 WARN MemoryStore: Not enough space to cache rdd_81_73 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:25 WARN MemoryStore: Not enough space to cache rdd_81_74 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:25 WARN MemoryStore: Not enough space to cache rdd_81_75 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:25 WARN MemoryStore: Not enough space to cache rdd_81_72 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:30 WARN MemoryStore: Not enough space to cache rdd_81_77 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:31 WARN MemoryStore: Not enough space to cache rdd_81_76 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:02:34 WARN MemoryStore: Not enough space to cache rdd_81_79 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:36 WARN MemoryStore: Not enough space to cache rdd_81_81 in memory! (computed 129.6 MiB so far)
# 25/06/20 10:02:36 WARN MemoryStore: Not enough space to cache rdd_81_80 in memory! (computed 292.2 MiB so far)
# 25/06/20 10:02:36 WARN MemoryStore: Not enough space to cache rdd_81_78 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:41 WARN MemoryStore: Not enough space to cache rdd_81_83 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:43 WARN MemoryStore: Not enough space to cache rdd_81_84 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:44 WARN MemoryStore: Not enough space to cache rdd_81_85 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:44 WARN MemoryStore: Not enough space to cache rdd_81_82 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:49 WARN MemoryStore: Not enough space to cache rdd_81_87 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:51 WARN MemoryStore: Not enough space to cache rdd_81_88 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:51 WARN MemoryStore: Not enough space to cache rdd_81_89 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:51 WARN MemoryStore: Not enough space to cache rdd_81_86 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:02:56 WARN MemoryStore: Not enough space to cache rdd_81_91 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:02:59 WARN MemoryStore: Not enough space to cache rdd_81_92 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:59 WARN MemoryStore: Not enough space to cache rdd_81_93 in memory! (computed 194.7 MiB so far)
# 25/06/20 10:02:59 WARN MemoryStore: Not enough space to cache rdd_81_90 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:03:04 WARN MemoryStore: Not enough space to cache rdd_81_95 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:03:05 WARN MemoryStore: Not enough space to cache rdd_81_94 in memory! (computed 1034.7 MiB so far)
# 25/06/20 10:03:07 WARN MemoryStore: Not enough space to cache rdd_81_97 in memory! (computed 689.2 MiB so far)
# 25/06/20 10:03:10 WARN MemoryStore: Not enough space to cache rdd_81_96 in memory! (computed 1553.0 MiB so far)
# 25/06/20 10:03:11 WARN MemoryStore: Not enough space to cache rdd_81_99 in memory! (computed 443.6 MiB so far)
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_49, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_64, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_57, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_2, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_99, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_18, which does not exist+ 4) / 17]
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_10, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_66, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_25, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_75, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_14, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_40, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_51, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_74, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_73, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_68, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_52, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_87, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_63, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_89, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_61, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_94, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_1, which does not exist
# 25/06/20 10:03:18 WARN BlockManager: Asked to remove block rdd_81_17, which does not exist
# [Stage 39:=======================================================================>    (16 + 1) / 17]
# Timp antrenare Random Forest: 11693.62 secunde
# 25/06/20 10:04:38 WARN DAGScheduler: Broadcasting large task binary with size 1215.6 KiB6 + 1) / 17]
# 25/06/20 10:47:08 WARN DAGScheduler: Broadcasting large task binary with size 1215.6 KiB6 + 1) / 17]
# 25/06/20 11:28:48 WARN DAGScheduler: Broadcasting large task binary with size 1215.6 KiB6 + 1) / 17]
# 25/06/20 12:10:28 WARN DAGScheduler: Broadcasting large task binary with size 1215.6 KiB6 + 1) / 17]
# [Stage 54:==========================================================================>(99 + 1) / 100]
# Acuratețe: 0.7640
# F1-score: 0.6969
# Precizie: 0.6734
# Recall: 0.7640
